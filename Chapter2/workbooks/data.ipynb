# %% [markdown]
# <a href="https://colab.research.google.com/github/emisseldine/OpenLinear/blob/main/Chapter2/workbooks/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.1 Vectors as Data
# ###We say that a vector is **sparse** if it only has a few nonzero entries. For Exercises 1-7 below, briefly describe what a sparse vector means in the given context.
#
# *Each of these exercises requires a text submission. This gives us an oppurtunity to practice with a Python notebook without the coding requirements. To print a string in Python, use the command `print('<string>')`, where you replace `<string>` with the output you want to display. An example is provided in Exercise 0. To 'execute' your code, hit the play/execute/run button or Ctrl+Shift. It should print your string as output. When completed, download the notebook as a .pdf file and upload it to the course's learning management system, e.g. Canvas.*

# %% [markdown]
# 0.  $\boldsymbol{x}$ is a medical profile for a patient containing $n$ medical quantities, say age, weight, height, blood
# pressure, etc.

# %%
print('A patient with few positive metrics, like 0 age, 0 weight, 0 height. Bizarre! Maybe an embryo?')
# Out:
# A patient with few positive metrics, like 0 age, 0 weight, 0 height. Bizarre! Maybe an embryo?

# %% [markdown]
# 1.  $\boldsymbol{x}$ is a bill of materials for a project containing n materials needed.

# %%
print('Answer here')

# %% [markdown]
# 2.   $\boldsymbol{x}$ is a vector recording the frequencies of $n$ categories observed in raw data, for example, keywords in
# a document.

# %%
print('Answer here')

# %% [markdown]
# 3.   $\boldsymbol{x}$ is the daily cash flow of a business over $n$ days.

# %%
print('Answer here')

# %% [markdown]
# 4.   $\boldsymbol{x}$ is a Boolean vector which records the presence of $n$ features.

# %%
print('Answer here')

# %% [markdown]
# 5.   $\boldsymbol{x}$ is the daily high temperature, in $F^\circ$, at a certain location over $n$ days.

# %%
print('Answer here')

# %% [markdown]
# 6.   $\boldsymbol{x}$ is an audio signal with $n$ samples.

# %%
print('Answer here')

# %% [markdown]
# 7.   $\boldsymbol{x}$ is a digital photo with $n$ pixels.

# %%
print('Answer here')
