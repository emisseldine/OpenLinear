# %% [markdown]
# <a href="https://colab.research.google.com/github/emisseldine/OpenLinear/blob/main/BackMatter/workbooks/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
#
#
# # Apx A Python Primer
# </center>
#
# ###For Exercises 1-5 below, write and execute the Python scripts.
#
#
# ---
#
#
# *An example is provided in Exercise 0. To execute your code, hit the play/execute/run button or Ctrl+Shift.*

# %% [markdown]
# 0.   Write two lines of Python code: the first line prints `"Hello!"`, and the second line prints `"Welcome to Linear Algebra!"`

# %%
print("Hello!")
print("Welcome to Linear Algebra!")
# Out:
# Hello!
# Welcome to Linear Algebra!

# %% [markdown]
# 1.   Create two variables, `a = 10` and `b = 3`. Compute their sum, difference, product, and quotient. For division, compute the quotient as a decimal and again with remainder. Print all results.

# %%
### EXERCISE 1#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# a,b=10,3
# print('sum = ',a+b)
# print('difference = ',a-b)
# print('product = ',a*b)
# print(f"quotient = {a/b} = {a//b}+{a%b}/{b}")
# ```
#
# </details>

# %% [markdown]
# 2.  Write a function `celsius_to_fahrenheit(c)` that takes a temperature in Celsius and returns the Fahrenheit equivalent using the formula:\
# $F = \dfrac{9}{5}C + 32$\
# Make sure to use a `return` statement. Verify your function on the input `c=0` and `c=100` degrees.

# %%
### EXERCISE 2#######################################
#Write your function here

print(celsius_to_fahrenheit(0),celsius_to_fahrenheit(100))

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```Python
# def celsius_to_fahrenheit(c):
#   return 9/5*c+32
#
# print(celsius_to_fahrenheit(0),celsius_to_fahrenheit(100))
# ```
#
# `32.0 212.0`
# </details>

# %% [markdown]
# 3.  Redo the previous exercise using a `lambda` function.

# %%
### EXERCISE 3#######################################
#Write your function here

print(celsius_to_fahrenheit(0),celsius_to_fahrenheit(100))

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```Python
# celsius_to_fahrenheit = lambda c: 9/5*c+32
#
#
# print(celsius_to_fahrenheit(0),celsius_to_fahrenheit(100))
# ```
#
# `32.0 212.0`
# </details>

# %% [markdown]
# 4.  Write a function `describe_number(x)` that determines if the number `x` is `"positive"`, `"negative"`, or `"zero"`. Use an `if` statement in your function. Verify your function on the input `4`, `0`, and `-10/3`.

# %%
### EXERCISE 4#######################################
#Write your function here

print(describe_number(4), describe_number(0), describe_number(-10/3))

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```Python
# def describe_number(x):
#   if x > 0:
#     return "positive"
#   elif x < 0:
#     return "negative"
#   else:
#     return "zero"
#
# print(describe_number(4), describe_number(0), describe_number(-10/3))
# ```
#
# `positive zero negative`
# </details>

# %% [markdown]
# 5.  Write a function `sum_up_to(n)` that calculates and returns the sum of all whole numbers from `1` up to `n`. Use an `for` statement in your function. Verify your function on the input `1`, `4`, and `100`.

# %%
### EXERCISE 5#######################################
#Write your function here

print(sum_up_to(1),sum_up_to(4),sum_up_to(100))

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```Python
# def sum_up_to(n):
#   sum = 0
#   for i in range(n+1):
#     sum += i
#   return sum
#
# print(sum_up_to(1),sum_up_to(4),sum_up_to(100))
# ```
#
# `1 10 5050`
# </details>

# %% [markdown]
# *When completed, download the notebook as a .pdf file and upload it to the course's learning management system, e.g. Canvas. To do this, via Google Chrome, choose `File`, then `Print` (or simply `Ctrl+P`). Then choose printer `Destination` as `Print as PDF.` You may have to adjust setting to print well. For example, set `Layout` as `Landscape` and under `More Settings` turn off `Headers and Footers`.*

# %% [markdown]
# ---
# <center>
#
# ##### This Python workbook was produced for [Linear Algebra Done Openly](https://github.com/emisseldine/OpenLinear) by Dr. Andrew Misseldine (2026).
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
# </center>
