# %% [markdown]
# <a href="https://colab.research.google.com/github/emisseldine/OpenLinear/blob/main/Chapter1/workbooks/linearapp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
#
#
# # 2.4 Applications of Linear Systems
# </center>
#
# ###For Exercise 1 below, solve the linear system.
#
#
# ---
#
#
# *To execute your code, hit the play/execute/run button or Ctrl+Shift.*

# %% [markdown]
# 1.   Michael is going to the store and offers to buy groceries for his friends. His friend, Bailey, says she needs 3 dozen eggs, 1 loaf of bread, and 7 apples. Another friend, Gaston, says he needs 5 dozen eggs, 2 loaves of bread, and 1 apple. His other friend, Janessa, says she needs 1 dozen eggs and 10 apples. After buying everything for his friends, he tells each of them what they should Venmo him. He tells Bailey her total is \$15.49, Gaston his total is \$18.32, and Janessa her total is \$10.29. How much does a loaf of bread, a dozen eggs, and a single apple cost?

# %%
import numpy as np

### EXERCISE 1#######################################
#Construct a 3x3 matrix A for orders of the roommates
#Construct a 3 vector b for their bills
#Use NumPy to solve the linear system.

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# The cost for one loaf of bread is \$2.39, for one dozen eggs is \$2.79, and one apple is \$0.79.
#
# </details>

# %% [markdown]
# ---
#
# ### For Exercises 2-4, interpolate the function $f$ through the given points.

# %% [markdown]
# 2.  $f(x) = a_3x^3+a_2x^2+a_1x+a_0$

# %%
### EXERCISE 2#######################################
# interpolate the function f(x) = a_0 + a_1x + a_2x^2 + a_3x^3 through the given points.
points = np.array([[1,1],[2,3],[4,0],[-1,-5]])
x = points[:,0]                   # just the x-coordinates
y= points[:,1]                    # just the y-coordinates

print("x = ",x)
print("y = ", y, "\n")

f = #construct your model here. You may need to construct the matrix A in the line above.
print(np.poly1d(f))


### VERIFICATION ############################
import matplotlib.pyplot as plt # matplotlib to print out our results in a graphic form
plt.style.use("seaborn-v0_8-whitegrid")

plt.ion()
domain = np.linspace(-6,6,100)
plt.xlim(-6,6)
plt.ylim(-10,10)
plt.scatter(x, y)
plt.plot(domain,f(domain))
plt.show()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $f(x)=-\dfrac{1}{6}x^3+\dfrac{19}{6}x-2$
#
# </details>

# %% [markdown]
# 3.  $f(x)=a_5x^5+a_4x^4+a_3x^3+a_2x^2+a_1x+a_0$

# %%
### EXERCISE 3#######################################
# interpolate the function f(x) = a_0 + a_1x + a_2x^2 + a_3x^3 + a_4x^4 + a_5x^5 through the given points.
points = np.array([[-2,231],[-1,19],[0,5],[1,9],[2,19],[3,-169]])
x = points[:,0]
y = points[:,1]

f = #construct your model here. You may need to construct the matrix A in the line above.
print(np.poly1d(f))

### VERIFICATION ############################
plt.ion()
t = np.linspace(-3,4,num = 100)
plt.axis([-3,4,-200,300])
plt.scatter(x,y)
plt.plot(t, np.poly1d(f)(t), 'r')
plt.show()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $f(x)=-3x^5+7x^4-x^3+2x^2-x+5$
#
# </details>

# %% [markdown]
# 4.  $f(x)=\dfrac{a_2x^2+a_1x+a_0}{b_2x^2+b_1x+1}$

# %%
### EXERCISE 4#######################################
# interpolate the function f(x) = (a_0 + a_1x + a_2x^2) / (1 + b_1x + b_2x^2) through the given points.
points = np.array([[-2,12/11],[-1,3/2],[0,2],[1,0],[2,0]])
x = points[:,0]
y = points[:,1]

f = #construct your model here. You may need to construct the matrix A in the line above.
numer = f[:n+1]
denom = np.concatenate((f[n+1:], [1]))
print(np.poly1d(numer), "/\n", np.poly1d(denom))

### VERIFICATION ############################
plt.axis([-3,4,-10,10])
plt.scatter(x,y)
plt.plot(t, np.polyval(numer,t) / np.polyval(denom,t), 'r')
plt.show()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $f(x)=\dfrac{x^2-3x+2}{2x^2-x+1}$
# </details>

# %% [markdown]
# *When completed, download the notebook as a .pdf file and upload it to the course's learning management system, e.g. Canvas. To do this, via Google Chrome, choose `File`, then `Print` (or simply `Ctrl+P`). Then choose printer `Destination` as `Print as PDF.` You may have to adjust setting to print well. For example, set `Layout` as `Landscape` and under `More Settings` turn off `Headers and Footers`.*

# %% [markdown]
# ---
# <center>
#
# ##### This Python workbook was produced for [Linear Algebra Done Openly](https://github.com/emisseldine/OpenLinear) by Dr. Andrew Misseldine (2026).
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
# </center>
