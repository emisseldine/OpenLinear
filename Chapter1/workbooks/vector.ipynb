# %% [markdown]
# <a href="https://colab.research.google.com/github/emisseldine/OpenLinear/blob/main/Chapter1/workbooks/vector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
#
#
# # 1.2 Vector Operations
# </center>
#
# ###For Exercises 1-2 below, simplify the linear combinations.
#
#
# ---
#
#
# *An example is provided in Exercise 0. To execute your code, hit the play/execute/run button or Ctrl+Shift.*

# %% [markdown]
# 0.   Compute $2\left[\begin{array}{r}5\\-7\end{array}\right] + \left[\begin{array}{r}-9\\6\end{array}\right]+0\left[\begin{array}{r}3\\-23\end{array}\right]$

# %%
import numpy as np

2*np.array([5,-7])+np.array([-9,6])+0*np.array([3,-23])
# Out:
# array([ 1, -8])

# %% [markdown]
# 1.   Compute $3\left[\begin{array}{r}-1\\0\\1\end{array}\right] + 2\left[\begin{array}{r}0\\0\\1\end{array}\right]-2\left[\begin{array}{r}3\\4\\0\end{array}\right]$.

# %%
### EXERCISE 1#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# 3*np.array([-1,0,1])+2*np.array([0,0,1])-2*np.array([3,4,0])
# ```
# $\left[\begin{array}{r}-9\\-8\\5\end{array}\right]$
#
# </details>

# %% [markdown]
# 2.  Compute $3\boldsymbol{x}-0.5\boldsymbol{y}$, given the vectors $\boldsymbol{x}$ and $\boldsymbol{y}$ below.

# %%
### EXERCISE 2#######################################
x = np.array([ 5.68926168, 6.48028365, 5.64919868, 4.64594575, 9.70900398, 8.2673083, 1.48566455, 9.48149181, 0.30697194, 8.19313516])
y= np.array([ 4.12159476, -0.90500151, -1.24963052, -4.18992406, 5.47895589, 6.658136, -4.20026454, -7.38517255, -2.03795684, -6.02101768])
print("x =", x)
print("y =", y, "\n")

print("3x-0.5y =", ) #compute the linear combination here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```Python
# solution = [15.00698766 19.8933517  17.5724113  16.03279928 26.387534   21.4728569  6.55712592 32.1370617   1.93989424 27.58991432]
# ```
#
# </details>

# %% [markdown]
# 3.  Compute $-4\boldsymbol{x}+3\boldsymbol{y}-\dfrac{1}{4}\boldsymbol{z}$, given the vectors $\boldsymbol{x}$, $\boldsymbol{y}$, and $\boldsymbol{z}$ below.

# %%
### EXERCISE 3#######################################
x = np.array([ 8.61629865, 5.63820846, 5.75495464, 8.93009079, 3.8037268, 5.54665841,1.81941849 , 3.957352789, 0.846544578, 7.018435392])
y = np.array([ 4.182946738, -4.09827890, -1.625413234, -7.980898765, 8.9026354178, 1.872543567, -6.16728987, -1.467827678, -2.098761524, -6.987896578])
z = np.array([8.192783464, 0.182734655, 8.162543786, -1.2345678, -.012378465, 3.1278965785, 5.678923511, 4.98761256, -1.89754008, 7.8910112])
print("x =", x)
print("y =", y)
print("z =", z, "\n")

print("-4x+3y-1/4z =", ) #compute the linear combination here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```Python
# solution = [-23.96455025 -34.8933542  -29.93669421 -59.3544175   11.49609367 -17.35097708 -27.19927445 -21.47979733  -9.20807786 -51.0101841 ]
# ```
#
# </details>

# %% [markdown]
# *When completed, download the notebook as a .pdf file and upload it to the course's learning management system, e.g. Canvas. To do this, via Google Chrome, choose `File`, then `Print` (or simply `Ctrl+P`). Then choose printer `Destination` as `Print as PDF.` You may have to adjust setting to print well. For example, set `Layout` as `Landscape` and under `More Settings` turn off `Headers and Footers`.*

# %% [markdown]
# ---
# <center>
#
# ##### This Python workbook was produced for [Linear Algebra Done Openly](https://github.com/emisseldine/OpenLinear) by Dr. Andrew Misseldine (2026).
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
# </center>
