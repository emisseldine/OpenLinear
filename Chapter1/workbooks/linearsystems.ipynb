# %% [markdown]
# <a href="https://colab.research.google.com/github/emisseldine/OpenLinear/blob/main/Chapter1/workbooks/linearsystems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
#
#
# # 2.1 Linear Systems
# </center>
#
# ###For Exercise 1 below, determine if the points are solutions to the following linear system.
#
#
# ---
#
#
# *An example is provided in Exercise 0. To execute your code, hit the play/execute/run button or Ctrl+Shift.*

# %% [markdown]
# 0.   Determine if the given points are solutions to the linear system
# $\begin{cases}
# x~~+y &=\quad\ 7\\
# 3x+3y-10z &=-79\\
# x~\ +5y+~~~~z &=~~~33.
# \end{cases}$
#
# i\. $(4,3,10)$\
# ii\. $(0,0,0)$\
# iii\. $(3,4,10)$\
# iv\. $(-10,3,-38)$

# %%
import numpy as np

IsLinearSolution = lambda A,b,x : np.array_equal(A@x,b) #Checks if A@x equals b

A = np.array([[1,1,0],[3,3,-10],[1,5,1]])
b = np.array([7,-79,33])

for x in [[4,3,10],[0,0,0],[3,4,10],[-10,3,-38]]:
  print(x,IsLinearSolution(A,b,x))
# Out:
# [4, 3, 10] False
# [0, 0, 0] False
# [3, 4, 10] True
# [-10, 3, -38] False

# %% [markdown]
# 1.   Determine if the given points are solutions to the linear system
# $\begin{cases}
# ~~~x+3y-2z &=13\\
# ~2x-~~y &=~~2\\
# -x+6y-4z &=17.
# \end{cases}$
#
# i\. $(6,10,4)$\
# ii\. $(5,8,8)$\
# iii\. $(3,4,1)$\
# iv\. $(9,3,2)$

# %%
### EXERCISE 1#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# A = np.array([[1,3,-2],[2,-1,0],[-1,6,-4]])
# b = np.array([13,2,17])
#
# for x in [[6,10,4],[5,8,8],[3,4,1],[9,3,2]]:
#   print(x,IsLinearSolution(A,b,x))
# ```
# [6, 10, 4] False\
# [5, 8, 8] False\
# [3, 4, 1] True\
# [9, 3, 2] False
#
# </details>

# %% [markdown]
# ---
#
# ### For Exercises 2-4, determine if the linear system is homogeneous. For those which are, find a solution.

# %% [markdown]
# 2.  $\begin{cases}
# 3x-~~y &=0\\
# 2x+5y &=0
# \end{cases}$

# %%
### EXERCISE 2#######################################
print('Solution') #report solution here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# homogeneous, $(0,0)$
#
# </details>

# %% [markdown]
# 3.  $\begin{cases}
# ~~~2x-4y &=0\\
# -6x+8y &=3
# \end{cases}$

# %%
### EXERCISE 3#######################################
print('Solution') #report solution here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# nonhomogeneous
#
# </details>

# %% [markdown]
# 4.  $\begin{cases}
# ~\quad x\qquad ~-2z &=0\\
# ~~~3x+4y+4z+~~w &=0\\
# -2x+6y+6z+2w &=0
# \end{cases}$

# %%
### EXERCISE 4#######################################
print('Solution') #report solution here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# homogeneous, $(0,0,0,0)$
#
# </details>

# %% [markdown]
# 5.  Using the general form \
# $(z+5,3z-1,z)$\
# for Example 2.1.4 \
# $\begin{cases}
# ~~~2x-~~y+~~~~z &=\quad11\\
# \quad~x+3y-10z &=\quad~2\\
# -3x+2y-~~3z &=-17
# \end{cases}$\
# from the book, construct five other solutions to the linear system from Example 2.1.4. Answers may vary.

# %%
### EXERCISE 5#######################################
print('Solution') #report solution here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# e.g. $(7,5,2)$,
# $(8,8,3)$,
# $(4,-4,-1)$,
# $(3,-7,-2)$,
# $(\pi+5,3\pi-1,\pi)$
#
# </details>

# %% [markdown]
# *When completed, download the notebook as a .pdf file and upload it to the course's learning management system, e.g. Canvas. To do this, via Google Chrome, choose `File`, then `Print` (or simply `Ctrl+P`). Then choose printer `Destination` as `Print as PDF.` You may have to adjust setting to print well. For example, set `Layout` as `Landscape` and under `More Settings` turn off `Headers and Footers`.*

# %% [markdown]
# ---
# <center>
#
# ##### This Python workbook was produced for [Linear Algebra Done Openly](https://github.com/emisseldine/OpenLinear) by Dr. Andrew Misseldine (2026).
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
# </center>
