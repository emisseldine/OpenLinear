# %% [markdown]
# <a href="https://colab.research.google.com/github/emisseldine/OpenLinear/blob/main/Chapter4/workbooks/inner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
#
#
# # 1.3 Inner Products
# </center>
#
# ###For Exercises 1-6 below, simplify the inner products.
#
#
# ---
#
#
# *An example is provided in Exercise 0. To execute your code, hit the play/execute/run button or Ctrl+Shift.*

# %% [markdown]
# 0.   Compute $\left[\begin{array}{r}1\\-1\end{array}\right] \cdot \left[\begin{array}{r}2\\-3\end{array}\right]$

# %%
import numpy as np

print(np.array([1,-1]) @ np.array([2,-3]))
# Out:
# 5

# %% [markdown]
# 1.   Compute $\left(3\left[\begin{array}{r}1\\-2\end{array}\right]\right) \cdot \left(2\left[\begin{array}{r}2\\-3\end{array}\right]\right)$.

# %%
### EXERCISE 1#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# (3*np.array([1,-2])) @ (2*np.array([2,-3]))
# ```
#
# $48$
#
# </details>

# %% [markdown]
# 2.   Compute $\left[\begin{array}{r}7\\1\\-5\end{array}\right] \cdot \left[\begin{array}{r}1\\-1\\2\end{array}\right]$.

# %%
### EXERCISE 2#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $-4$
#
# </details>

# %% [markdown]
# 3.   Compute $\left(\left[\begin{array}{r}1\\-5\\0\end{array}\right]+\left[\begin{array}{r}3\\2\\-3\end{array}\right]\right) \cdot \left[\begin{array}{r}1\\0\\-1\end{array}\right]$.

# %%
### EXERCISE 3#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $7$
#
# </details>

# %% [markdown]
# 4.   Compute $\left(2\left[\begin{array}{r}-1\\-1\\3\end{array}\right]\right)\cdot\left(\left[\begin{array}{r}1\\-2\\1\end{array}\right]+\left[\begin{array}{r}0\\-5\\3\end{array}\right]\right)$.

# %%
### EXERCISE 4#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $36$
#
# </details>

# %% [markdown]
# 5.   Compute $\left[\begin{array}{r}2\\1\\-3\\2\end{array}\right]\cdot\left[\begin{array}{r}7\\1\\-1\\2\end{array}\right]$.

# %%
### EXERCISE 5#######################################

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# $22$
#
# </details>

# %% [markdown]
# 6.  Compute $\boldsymbol{x}\cdot\boldsymbol{y}$, given the vectors $\boldsymbol{x}$ and $\boldsymbol{y}$ below.

# %%
### EXERCISE 6#######################################
x = np.array([ 5.68926168, 6.48028365, 5.64919868, 4.64594575, 9.70900398, 8.2673083, 1.48566455, 9.48149181, 0.30697194, 8.19313516])
y= np.array([ 4.12159476, -0.90500151, -1.24963052, -4.18992406, 5.47895589, 6.658136, -4.20026454, -7.38517255, -2.03795684, -6.02101768])
print("x =", x)
print("y =", y)

print("x@y =", ) #compute dot product here.

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```Python
# solution = -26.920583159552294
# ```
#
# </details>

# %% [markdown]
# *When completed, download the notebook as a .pdf file and upload it to the course's learning management system, e.g. Canvas. To do this, via Google Chrome, choose `File`, then `Print` (or simply `Ctrl+P`). Then choose printer `Destination` as `Print as PDF.` You may have to adjust setting to print well. For example, set `Layout` as `Landscape` and under `More Settings` turn off `Headers and Footers`.*

# %% [markdown]
# ---
# <center>
#
# ##### This Python workbook was produced for [Linear Algebra Done Openly](https://github.com/emisseldine/OpenLinear) by Dr. Andrew Misseldine (2026).
# <p style="text-align:center">
#     <a href="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" target="_blank">
#     <img src="https://raw.githubusercontent.com/emisseldine/OpenLinear/main/BackMatter/logo.png" width="200" alt="Missel Books Logo">
#     </a>
# </p>
# </center>
